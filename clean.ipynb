# %%
import pandas as pd
import numpy as np

data = pd.read_csv('Employee.csv')

# %%
data
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 0                             0           0
# 1                             3           1
# 2                             2           0
# 3                             5           1
# 4                             2           1
# ...                         ...         ...
# 4648                          4           0
# 4649                          2           1
# 4650                          5           1
# 4651                          2           0
# 4652                          4           0
#
# [4653 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB

# %%
data.groupby(['City']).size()
# Out:
# City
# Bangalore    2228
# New Delhi    1157
# Pune         1268
# dtype: int64

# %%
data.loc[data['City'] == 'Bangalore', 'City'] = 'A'
data.loc[data['City'] == 'New Delhi', 'City'] = 'B'
data.loc[data['City'] == 'Pune', 'City'] = 'C'

# %%
data
# Out:
#       Education  JoiningYear City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017    A            3   34    Male          No
# 1     Bachelors         2013    C            1   28  Female          No
# 2     Bachelors         2014    B            3   38  Female          No
# 3       Masters         2016    A            3   27    Male          No
# 4       Masters         2017    C            3   24    Male         Yes
# ...         ...          ...  ...          ...  ...     ...         ...
# 4648  Bachelors         2013    A            3   26  Female          No
# 4649    Masters         2013    C            2   37    Male          No
# 4650    Masters         2018    B            3   27    Male          No
# 4651  Bachelors         2012    A            3   30    Male         Yes
# 4652  Bachelors         2015    A            3   33    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 0                             0           0
# 1                             3           1
# 2                             2           0
# 3                             5           1
# 4                             2           1
# ...                         ...         ...
# 4648                          4           0
# 4649                          2           1
# 4650                          5           1
# 4651                          2           0
# 4652                          4           0
#
# [4653 rows x 9 columns]

# %%
data.to_pickle('Clean_data.pickle')

# %%
def splitData(dataframe, percent_train):
    m = data.shape[0]
    n_train = int(np.ceil(percent_train * m))
    n_test = m - n_train
    index_train = list(np.sort(np.random.choice(m, n_train, replace=False)))
    data_train = dataframe.iloc[index_train]

    ALL = set(range(m))
    TRAIN = set(index_train)
    TEST = ALL - TRAIN

    index_test = sorted(list(TEST))
    data_test = dataframe.iloc[index_test]
    
    return (data_train, data_test)


(data_train, data_test) = splitData(data, 0.7)

# %%
data_train
# Out:
#       Education  JoiningYear City  PaymentTier  Age  Gender EverBenched  \
# 1     Bachelors         2013    C            1   28  Female          No
# 2     Bachelors         2014    B            3   38  Female          No
# 3       Masters         2016    A            3   27    Male          No
# 5     Bachelors         2016    A            3   22    Male          No
# 6     Bachelors         2015    B            3   38    Male          No
# ...         ...          ...  ...          ...  ...     ...         ...
# 4647  Bachelors         2016    C            3   30    Male          No
# 4648  Bachelors         2013    A            3   26  Female          No
# 4649    Masters         2013    C            2   37    Male          No
# 4650    Masters         2018    B            3   27    Male          No
# 4651  Bachelors         2012    A            3   30    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 1                             3           1
# 2                             2           0
# 3                             5           1
# 5                             0           0
# 6                             0           0
# ...                         ...         ...
# 4647                          2           0
# 4648                          4           0
# 4649                          2           1
# 4650                          5           1
# 4651                          2           0
#
# [3258 rows x 9 columns]

# %%
data_test.to_pickle('Data_test.pickle')

# %%
data_train.to_pickle('Data_train.pickle')
