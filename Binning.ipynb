# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb


dt = pd.read_pickle('Data_train.pickle')

dt
# Out:
#       Education  JoiningYear City  PaymentTier  Age  Gender EverBenched  \
# 1     Bachelors         2013    C            1   28  Female          No
# 2     Bachelors         2014    B            3   38  Female          No
# 3       Masters         2016    A            3   27    Male          No
# 4       Masters         2017    C            3   24    Male         Yes
# 6     Bachelors         2015    B            3   38    Male          No
# ...         ...          ...  ...          ...  ...     ...         ...
# 4647  Bachelors         2016    C            3   30    Male          No
# 4648  Bachelors         2013    A            3   26  Female          No
# 4649    Masters         2013    C            2   37    Male          No
# 4650    Masters         2018    B            3   27    Male          No
# 4651  Bachelors         2012    A            3   30    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 1                             3           1
# 2                             2           0
# 3                             5           1
# 4                             2           1
# 6                             0           0
# ...                         ...         ...
# 4647                          2           0
# 4648                          4           0
# 4649                          2           1
# 4650                          5           1
# 4651                          2           0
#
# [3258 rows x 9 columns]

# %%
fields = ['JoiningYear','Age','ExperienceInCurrentDomain']
for f in fields:
    fbin = pd.qcut(dt[f], 10, duplicates = 'drop')
    print(fbin)
    fname = f.upper() + '_BIN'
    dt[fname] = fbin
    dt
    fig = plt.figure(figsize = (15,8))
    sb.countplot(data = dt, x = fname)
# Out:
# 1       (2011.999, 2013.0]
# 2         (2013.0, 2014.0]
# 3         (2015.0, 2016.0]
# 4         (2016.0, 2017.0]
# 6         (2014.0, 2015.0]
#                ...
# 4647      (2015.0, 2016.0]
# 4648    (2011.999, 2013.0]
# 4649    (2011.999, 2013.0]
# 4650      (2017.0, 2018.0]
# 4651    (2011.999, 2013.0]
# Name: JoiningYear, Length: 3258, dtype: category
# Categories (6, interval[float64]): [(2011.999, 2013.0] < (2013.0, 2014.0] < (2014.0, 2015.0] < (2015.0, 2016.0] < (2016.0, 2017.0] < (2017.0, 2018.0]]
# 1         (27.0, 28.0]
# 2         (34.0, 38.0]
# 3         (26.0, 27.0]
# 4       (21.999, 24.0]
# 6         (34.0, 38.0]
#              ...
# 4647      (29.0, 31.0]
# 4648      (24.0, 26.0]
# 4649      (34.0, 38.0]
# 4650      (26.0, 27.0]
# 4651      (29.0, 31.0]
# Name: Age, Length: 3258, dtype: category
# Categories (9, interval[float64]): [(21.999, 24.0] < (24.0, 26.0] < (26.0, 27.0] < (27.0, 28.0] ... (29.0, 31.0] < (31.0, 34.0] < (34.0, 38.0] < (38.0, 41.0]]
# 1          (2.0, 3.0]
# 2          (1.0, 2.0]
# 3          (4.0, 5.0]
# 4          (1.0, 2.0]
# 6       (-0.001, 1.0]
#             ...
# 4647       (1.0, 2.0]
# 4648       (3.0, 4.0]
# 4649       (1.0, 2.0]
# 4650       (4.0, 5.0]
# 4651       (1.0, 2.0]
# Name: ExperienceInCurrentDomain, Length: 3258, dtype: category
# Categories (6, interval[float64]): [(-0.001, 1.0] < (1.0, 2.0] < (2.0, 3.0] < (3.0, 4.0] < (4.0, 5.0] < (5.0, 7.0]]

# %%
dt.to_pickle('Binning.pickle')

# %%
dt
# Out:
#       Education  JoiningYear City  PaymentTier  Age  Gender EverBenched  \
# 1     Bachelors         2013    C            1   28  Female          No
# 2     Bachelors         2014    B            3   38  Female          No
# 3       Masters         2016    A            3   27    Male          No
# 4       Masters         2017    C            3   24    Male         Yes
# 6     Bachelors         2015    B            3   38    Male          No
# ...         ...          ...  ...          ...  ...     ...         ...
# 4647  Bachelors         2016    C            3   30    Male          No
# 4648  Bachelors         2013    A            3   26  Female          No
# 4649    Masters         2013    C            2   37    Male          No
# 4650    Masters         2018    B            3   27    Male          No
# 4651  Bachelors         2012    A            3   30    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot     JOININGYEAR_BIN  \
# 1                             3           1  (2011.999, 2013.0]
# 2                             2           0    (2013.0, 2014.0]
# 3                             5           1    (2015.0, 2016.0]
# 4                             2           1    (2016.0, 2017.0]
# 6                             0           0    (2014.0, 2015.0]
# ...                         ...         ...                 ...
# 4647                          2           0    (2015.0, 2016.0]
# 4648                          4           0  (2011.999, 2013.0]
# 4649                          2           1  (2011.999, 2013.0]
# 4650                          5           1    (2017.0, 2018.0]
# 4651                          2           0  (2011.999, 2013.0]
#
#              AGE_BIN EXPERIENCEINCURRENTDOMAIN_BIN
# 1       (27.0, 28.0]                    (2.0, 3.0]
# 2       (34.0, 38.0]                    (1.0, 2.0]
# 3       (26.0, 27.0]                    (4.0, 5.0]
# 4     (21.999, 24.0]                    (1.0, 2.0]
# 6       (34.0, 38.0]                 (-0.001, 1.0]
# ...              ...                           ...
# 4647    (29.0, 31.0]                    (1.0, 2.0]
# 4648    (24.0, 26.0]                    (3.0, 4.0]
# 4649    (34.0, 38.0]                    (1.0, 2.0]
# 4650    (26.0, 27.0]                    (4.0, 5.0]
# 4651    (29.0, 31.0]                    (1.0, 2.0]
#
# [3258 rows x 12 columns]
