# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb


dt = pd.read_pickle('Data_train.pickle')

dt
# Out:
#     Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 1        1       2          1         1             1             4583
# 2        1       2          0         1             0             3000
# 3        1       2          0         0             1             2583
# 4        1       1          0         1             1             6000
# 6        1       2          0         0             1             2333
# ..     ...     ...        ...       ...           ...              ...
# 494      1       2          0         1             1             3597
# 495      0       2          1         1             1             3326
# 496      1       2          0         0             1             2600
# 497      1       2          0         1             1             4625
# 499      1       1          0         1             1             6283
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# ...

# %%
fields = ['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term']
for f in fields:
    fbin = pd.qcut(dt[f], 10, duplicates = 'drop')
    print(fbin)
    fname = f.upper() + '_BIN'
    dt[fname] = fbin
    dt
    fig = plt.figure(figsize = (15,8))
    sb.countplot(data = dt, x = fname)
# Out:
# 1       (4442.2, 5244.1]
# 2       (2645.8, 3083.3]
# 3       (2333.0, 2645.8]
# 4       (5244.1, 6524.8]
# 6      (209.999, 2333.0]
#              ...
# 494     (3499.4, 3934.0]
# 495     (3083.3, 3499.4]
# 496     (2333.0, 2645.8]
# 497     (4442.2, 5244.1]
# 499     (5244.1, 6524.8]
# Name: ApplicantIncome, Length: 338, dtype: category
# Categories (10, interval[float64]): [(209.999, 2333.0] < (2333.0, 2645.8] < (2645.8, 3083.3] < (3083.3, 3499.4] ... (4442.2, 5244.1] < (5244.1, 6524.8] < (6524.8, 9505.2] < (9505.2, 63337.0]]
# 1       (1061.5, 1640.8]
# 2       (-0.001, 1061.5]
# 3       (2032.0, 2462.8]
# 4       (-0.001, 1061.5]
# 6       (1061.5, 1640.8]
#              ...
# 494     (2032.0, 2462.8]
# 495     (-0.001, 1061.5]
# 496     (1640.8, 2032.0]
# 497     (2462.8, 3750.0]
# 499    (3750.0, 20000.0]
# Name: CoapplicantIncome, Length: 338, dtype: category
# ...

# %%
sb.histplot(dt['Education'])
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Count'>

# %%
dt
# Out:
#     Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 1        1       2          1         1             1             4583
# 2        1       2          0         1             0             3000
# 3        1       2          0         0             1             2583
# 4        1       1          0         1             1             6000
# 6        1       2          0         0             1             2333
# ..     ...     ...        ...       ...           ...              ...
# 494      1       2          0         1             1             3597
# 495      0       2          1         1             1             3326
# 496      1       2          0         0             1             2600
# 497      1       2          0         1             1             4625
# 499      1       1          0         1             1             6283
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# ...

# %%
dt.to_pickle('Loan_Binning.pickle')
